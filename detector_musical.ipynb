# %% [markdown]
# <a href="https://colab.research.google.com/github/laduqueo/Senales_y_Sistemas/blob/main/detector_musical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar yt-dlp y otras dependencias necesarias
# !pip install streamlit
# !pip install -q yt-dlp gdown soundfile scikit-learn
# !apt-get -qq install ffmpeg
# Out:
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.41.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 90.3 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 101.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.45.1 watchdog-6.0.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 83.0 MB/s eta 0:00:00

# %%
# ——————————————————————————————————————————————————————————————————————————
# 1. DESCARGA DE CANCIONES DESDE EL EXCEL
# ——————————————————————————————————————————————————————————————————————————

# Instalamos gdown si no está disponible (solo si estás en Colab o entorno nuevo)
try:
    import gdown
except ImportError:
    import os
    os.system('pip install gdown')
    import gdown

# Identificador de tu Google Sheet con las 30 canciones
FILEID = "1HZ3-I9dSYyrV3JGDd-E1BPV_JVzVzV-j"

# Descargamos el Excel desde Google Drive con gdown
gdown.download(f"https://drive.google.com/uc?id={FILEID}", "canciones.xlsx", quiet=False)

import pandas as pd
import numpy as np
import os
import subprocess
import yt_dlp as youtube_dl
import soundfile as sf

# Leemos el Excel que contiene: link, band, type, type_num
X = pd.read_excel("canciones.xlsx")

# Creamos la carpeta donde guardaremos mp3 y wav
os.makedirs('results', exist_ok=True)

# Función para descargar un video de YouTube como MP3
def download_ytvid_as_mp3(video_url, name):
    video_info = youtube_dl.YoutubeDL().extract_info(url=video_url, download=False)
    filename = f"{name}.mp3"
    options = {
        'format': 'bestaudio/best',
        'keepvideo': False,
        'outtmpl': filename,
    }
    with youtube_dl.YoutubeDL(options) as ydl:
        ydl.download([video_info['webpage_url']])
    print(f"Download complete: {filename}")

# Iteramos sobre las filas del Excel, descargamos y convertimos a WAV
N = len(X)
for n in range(N):
    link  = X.loc[n, 'link']
    band  = X.loc[n, 'band']
    tnum  = X.loc[n, 'type_num']
    name_ = f"results/{band}_{n}_{tnum}"
    print(f"\n=== Descargando canción {n+1}/{N} ===")
    print(f"Link: {link}")
    download_ytvid_as_mp3(link, name_)
    # Convertimos el MP3 a WAV (48 kHz, estéreo si aplica)
    subprocess.call([
        'ffmpeg', '-y',
        '-i', f"{name_}.mp3",
        '-ar', '48000',   # sample rate 48 kHz
        '-ac', '2',       # 2 canales estéreo
        f"{name_}.wav"
    ])
    # Borramos el mp3 original para ahorrar espacio
    os.remove(f"{name_}.mp3")


# ——————————————————————————————————————————————————————————————————————————
# 2. PARTICIONAR CADA WAV EN 5 FRAGMENTOS DE 5 SEGUNDOS → 50 MUESTRAS TOTALES
# ——————————————————————————————————————————————————————————————————————————

# Listamos todos los archivos .wav que acabamos de generar
path = 'results/'
wav_files = [f for f in os.listdir(path) if f.endswith('.wav')]
print(f"\nTotal de archivos WAV encontrados: {len(wav_files)} (deberían ser 10)")

# Parámetros de segmentación
fs = 48000            # frecuencia de muestreo (48 kHz)
ts = 5                # duración de cada segmento en segundos
# Para obtener 50 segmentos en total a partir de 10 canciones,
# necesitamos 5 offsets (5 segundos de duración) por cada canción:
tl = [10,  40,  70, 100, 130]   # instantes (en segundos) donde empieza cada fragmento de 5 s

Ns = len(wav_files) * len(tl)   # 10 canciones × 5 offsets = 50 segmentos
# Preasignamos arrays:
x_t    = np.zeros((Ns, int(ts*fs), 2), dtype=np.float32)  # Ns segmentos, muestras (5s×48kHz), 2 canales
label  = np.zeros((Ns, 1),  dtype=int)                    # etiqueta de género (1 o 2)
name_c = []                                               # nombre de canción (sin sufijo "_n_type")

i = 0
for name in wav_files:
    filepath = os.path.join(path, name)
    x, fs_file = sf.read(filepath)    # x.shape = (total_muestras, 2)
    if fs_file != fs:
        raise RuntimeError(f"Esperamos 48 kHz, pero {name} está a {fs_file} Hz")
    # Etiqueta de género tomada del penúltimo carácter antes de ".wav": "..._{type}.wav"
    genre_num = int(name[-5])  # asumiendo formato "..._{type}.wav"
    base_name = name[:-6]      # para evitar "..._n_t.wav"
    for ti_seg in tl:
        start = int(ti_seg * fs)
        end   = int((ti_seg + ts) * fs)
        x_t[i]   = x[start:end, :]      # recortamos 5 segundos (estéreo)
        label[i] = genre_num
        name_c.append(base_name)
        print(f"{i:02d} → {name}   segundos {ti_seg}:{ti_seg+ts}   género {genre_num}")
        i += 1

print(f"\nForma de x_t: {x_t.shape}   → 50 segmentos de 5 s en estéreo")
print(f"Forma de label: {label.shape}")

# ——————————————————————————————————————————————————————————————————————————
# 3. CÁLCULO DE LA FFT Y NORMALIZACIÓN DE CADA SEGMENTO
# ——————————————————————————————————————————————————————————————————————————

# 3.A. Construimos el vector de frecuencias completo para rfft (para ts×fs muestras)
vf = np.fft.rfftfreq(int(ts*fs), 1/fs)

# 3.B. Calculamos la FFT real para cada segmento (axis=1 recorre el tiempo)
#      Luego promediamos ambos canales en el dominio de magnitudes.
Xw = np.fft.rfft(x_t, axis=1)          # shape = (50, N_bins, 2)
Xw_mag = np.mean(np.abs(Xw), axis=2)   # shape = (50, N_bins)

# 3.C. Escogemos un fmax razonable (p. ej. 7000 Hz) para recortar el espectro
fmax = 7000
fmax_idx = np.argmin(np.abs(vf - fmax))  # índice del bin más cercano a fmax
print(f"\nBin máximo seleccionado (f <= {fmax} Hz):  {fmax_idx}  (f = {vf[fmax_idx]:.1f} Hz)")

# 3.D. Cortamos el espectro a [0 : fmax_idx]
Xw_crop = Xw_mag[:, :fmax_idx]

# 3.E. Normalizamos entre 0 y 1 cada vector de frecuencias
from sklearn.preprocessing import MinMaxScaler
sca = MinMaxScaler()
Xw_norm = sca.fit_transform(Xw_crop)   # shape = (50, fmax_idx)

print(f"Dataset final de espectros normalizados:  {Xw_norm.shape}   (50 muestras × {fmax_idx} bins)")

# ——————————————————————————————————————————————————————————————————————————
# 4. VISUALIZACIÓN RÁPIDA Y SEPARABILIDAD 2D
# ——————————————————————————————————————————————————————————————————————————

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# 4.A. Graficar magnitud del primer segmento (solo para verificar)
plt.figure(figsize=(6,3))
plt.plot(vf[:fmax_idx], Xw_norm[0], color='tab:blue')
plt.title("Espectro normalizado (fragmento #0)")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud normalizada")
plt.grid(True)
plt.show()

# 4.B. Separabilidad 2D usando TSNE
red_ = TSNE(perplexity=20, n_components=2, random_state=123, learning_rate='auto', init='pca')
X_2D = red_.fit_transform(Xw_norm)  # shape = (50, 2)

# Graficar scatter con colorbar
plt.figure(figsize=(5,4))
plt.scatter(X_2D[:,0], X_2D[:,1], c=label.ravel(), cmap='viridis', s=20)
plt.colorbar(label="Género (1 vs 2)")
plt.title("Separabilidad 2D (TSNE) de los 50 segmentos")
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.grid(True)
plt.show()

# Graficar scatter con nombres de canciones
color_ = ["b", "y"]
plt.figure(figsize=(5,4))
plt.scatter(X_2D[:,0], X_2D[:,1], c=label.ravel(), s=10, cmap='viridis')
for idx, tex in enumerate(name_c):
    plt.text(
        X_2D[idx,0] * 1.025,
        X_2D[idx,1] * 1.025,
        tex.split('/')[-1],
        fontsize=6,
        color=color_[int(label[idx,0] - 1)]
    )
plt.title("Mapa 2D con etiquetas de canciones")
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.grid(True)
plt.show()

# ——————————————————————————————————————————————————————————————————————————
# 5. ENTRENAMIENTO DEL CLASIFICADOR KNN (DISTANCIA EUCLÍDEA)
# ——————————————————————————————————————————————————————————————————————————

from sklearn.neighbors import KNeighborsClassifier
import joblib

knn = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
knn.fit(Xw_norm, label.ravel())

os.makedirs('modelo', exist_ok=True)
joblib.dump({
    'knn_model': knn,
    'scaler'   : sca,
    'fmax_idx' : fmax_idx,
    'vf'       : vf[:fmax_idx],
    'fs'       : fs
}, 'modelo/knn_genre_detector.pkl')

print("\n—> Entrenamiento completado: 50 vectores (5 s cada uno) con KNN guardado en modelo/knn_genre_detector.pkl\n")

# ——————————————————————————————————————————————————————————————————————————
# 6. CREAR UN FRAGMENTO DE PRUEBA EXTRAÍDO DE LOS 50 SEGMENTOS Y GUARDARLO COMO WAV
# ——————————————————————————————————————————————————————————————————————————

i_test = 32
test_fragment = x_t[i_test]   # forma (240000, 2)
sf.write("nuevo_fragmento_5s.wav", test_fragment, fs)
print(f"→ Se creó 'nuevo_fragmento_5s.wav' a partir del segmento #{i_test} (género real = {int(label[i_test,0])})\n")

# ——————————————————————————————————————————————————————————————————————————
# 7. FUNCIÓN PARA DETECTAR GÉNERO DE UN NUEVO FRAGMENTO DE 5 s
# ——————————————————————————————————————————————————————————————————————————

def predict_genre_from_wav(new_wav_path: str, model_path: str = 'modelo/knn_genre_detector.pkl'):
    """
    Carga un archivo WAV de exactamente 5 segundos (mono o estéreo),
    calcula su FFT, recorta hasta fmax_idx, normaliza con el mismo MinMaxScaler
    y predice el género usando el KNN entrenado.
    Devuelve la etiqueta (1 o 2).
    """
    mdl = joblib.load(model_path)
    knn_loaded = mdl['knn_model']
    sca_loaded = mdl['scaler']
    fmax_idx  = mdl['fmax_idx']
    fs_ref    = mdl['fs']

    x5, fs_file = sf.read(new_wav_path)
    if fs_file != fs_ref:
        raise ValueError(f"El WAV está a {fs_file} Hz; debe estar a {fs_ref} Hz.")
    n5 = 5 * fs_ref
    if x5.ndim == 1:
        if x5.shape[0] < n5:
            raise ValueError("El archivo WAV es más corto de 5 segundos.")
        x5_seg = x5[:n5]
    else:
        if x5.shape[0] < n5:
            raise ValueError("El WAV (estéreo) es más corto de 5 segundos.")
        x5_seg = x5[:n5, :]

    if x5_seg.ndim == 1:
        Xw5 = np.abs(np.fft.rfft(x5_seg))
    else:
        Xw5_0 = np.abs(np.fft.rfft(x5_seg[:, 0]))
        Xw5_1 = np.abs(np.fft.rfft(x5_seg[:, 1]))
        Xw5   = (Xw5_0 + Xw5_1) / 2.0

    mag5_crop = Xw5[:fmax_idx].reshape(1, -1)
    mag5_norm = sca_loaded.transform(mag5_crop)

    pred = knn_loaded.predict(mag5_norm)[0]
    return int(pred)

# ——————————————————————————————————————————————————————————————————————————
# 8. EJEMPLO DE USO DEL DETECTOR (SE PREDICE SOBRE 'nuevo_fragmento_5s.wav')
# ——————————————————————————————————————————————————————————————————————————

nuevo_fragmento = "nuevo_fragmento_5s.wav"  # creado en el paso anterior

try:
    genero_predicho = predict_genre_from_wav(nuevo_fragmento)
    print(f"\n¡Género predicho para '{nuevo_fragmento}': {genero_predicho}  (1=Pop, 2=Vallenato)!\n")
    display(Audio(nuevo_fragmento, rate=fs))
except Exception as e:
    print("Error al predecir género:", e)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1HZ3-I9dSYyrV3JGDd-E1BPV_JVzVzV-j
# To: /content/canciones.xlsx
# 100%|██████████| 13.2k/13.2k [00:00<00:00, 25.3MB/s]
# === Descargando canción 1/40 ===
# Link: https://www.youtube.com/watch?v=tmhFWw6tiAo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tmhFWw6tiAo
# [youtube] tmhFWw6tiAo: Downloading webpage
# [youtube] tmhFWw6tiAo: Downloading tv client config
# [youtube] tmhFWw6tiAo: Downloading player 94f771d8-main
# [youtube] tmhFWw6tiAo: Downloading tv player API JSON
# [youtube] tmhFWw6tiAo: Downloading ios player API JSON
# [youtube] tmhFWw6tiAo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tmhFWw6tiAo
# [youtube] tmhFWw6tiAo: Downloading webpage
# [youtube] tmhFWw6tiAo: Downloading tv client config
# [youtube] tmhFWw6tiAo: Downloading tv player API JSON
# [youtube] tmhFWw6tiAo: Downloading ios player API JSON
# [youtube] tmhFWw6tiAo: Downloading m3u8 information
# [info] tmhFWw6tiAo: Downloading 1 format(s): 251
# [download] Destination: results/abba_0_1.mp3
# [download] 100% of    4.02MiB in 00:00:00 at 9.69MiB/s
# Download complete: results/abba_0_1.mp3
#
# === Descargando canción 2/40 ===
# Link: https://www.youtube.com/watch?v=5NV6Rdv1a3I
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5NV6Rdv1a3I
# [youtube] 5NV6Rdv1a3I: Downloading webpage
# [youtube] 5NV6Rdv1a3I: Downloading tv client config
# [youtube] 5NV6Rdv1a3I: Downloading tv player API JSON
# [youtube] 5NV6Rdv1a3I: Downloading ios player API JSON
# [youtube] 5NV6Rdv1a3I: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5NV6Rdv1a3I
# [youtube] 5NV6Rdv1a3I: Downloading webpage
# [youtube] 5NV6Rdv1a3I: Downloading tv client config
# [youtube] 5NV6Rdv1a3I: Downloading tv player API JSON
# [youtube] 5NV6Rdv1a3I: Downloading ios player API JSON
# [youtube] 5NV6Rdv1a3I: Downloading m3u8 information
# [info] 5NV6Rdv1a3I: Downloading 1 format(s): 251
# [download] Destination: results/daftpunk_1_1.mp3
# [download] 100% of    3.97MiB in 00:00:00 at 38.23MiB/s
# Download complete: results/daftpunk_1_1.mp3
#
# === Descargando canción 3/40 ===
# Link: https://www.youtube.com/watch?v=V9PVRfjEBTI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=V9PVRfjEBTI
# [youtube] V9PVRfjEBTI: Downloading webpage
# [youtube] V9PVRfjEBTI: Downloading tv client config
# [youtube] V9PVRfjEBTI: Downloading tv player API JSON
# [youtube] V9PVRfjEBTI: Downloading ios player API JSON
# [youtube] V9PVRfjEBTI: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=V9PVRfjEBTI
# [youtube] V9PVRfjEBTI: Downloading webpage
# [youtube] V9PVRfjEBTI: Downloading tv client config
# [youtube] V9PVRfjEBTI: Downloading tv player API JSON
# [youtube] V9PVRfjEBTI: Downloading ios player API JSON
# [youtube] V9PVRfjEBTI: Downloading m3u8 information
# [info] V9PVRfjEBTI: Downloading 1 format(s): 251
# [download] Destination: results/billieeilish_2_1.mp3
# [download] 100% of    3.44MiB in 00:00:00 at 60.87MiB/s
# Download complete: results/billieeilish_2_1.mp3
#
# === Descargando canción 4/40 ===
# Link: https://www.youtube.com/watch?v=ulZQTrV8QlQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ulZQTrV8QlQ
# [youtube] ulZQTrV8QlQ: Downloading webpage
# [youtube] ulZQTrV8QlQ: Downloading tv client config
# [youtube] ulZQTrV8QlQ: Downloading tv player API JSON
# [youtube] ulZQTrV8QlQ: Downloading ios player API JSON
# [youtube] ulZQTrV8QlQ: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ulZQTrV8QlQ
# [youtube] ulZQTrV8QlQ: Downloading webpage
# [youtube] ulZQTrV8QlQ: Downloading tv client config
# [youtube] ulZQTrV8QlQ: Downloading tv player API JSON
# [youtube] ulZQTrV8QlQ: Downloading ios player API JSON
# [youtube] ulZQTrV8QlQ: Downloading m3u8 information
# [info] ulZQTrV8QlQ: Downloading 1 format(s): 251
# [download] Destination: results/abba_3_1.mp3
# [download] 100% of    4.36MiB in 00:00:00 at 54.83MiB/s
# Download complete: results/abba_3_1.mp3
#
# === Descargando canción 5/40 ===
# Link: https://www.youtube.com/watch?v=ekr2nIex040
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ekr2nIex040
# [youtube] ekr2nIex040: Downloading webpage
# [youtube] ekr2nIex040: Downloading tv client config
# [youtube] ekr2nIex040: Downloading tv player API JSON
# [youtube] ekr2nIex040: Downloading ios player API JSON
# [youtube] ekr2nIex040: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ekr2nIex040
# [youtube] ekr2nIex040: Downloading webpage
# [youtube] ekr2nIex040: Downloading tv client config
# [youtube] ekr2nIex040: Downloading tv player API JSON
# [youtube] ekr2nIex040: Downloading ios player API JSON
# [youtube] ekr2nIex040: Downloading m3u8 information
# [info] ekr2nIex040: Downloading 1 format(s): 251
# [download] Destination: results/roseybruno_4_1.mp3
# [download] 100% of    2.59MiB in 00:00:00 at 21.27MiB/s
# Download complete: results/roseybruno_4_1.mp3
#
# === Descargando canción 6/40 ===
# Link: https://www.youtube.com/watch?v=H5v3kku4y6Q
# [youtube] Extracting URL: https://www.youtube.com/watch?v=H5v3kku4y6Q
# [youtube] H5v3kku4y6Q: Downloading webpage
# [youtube] H5v3kku4y6Q: Downloading tv client config
# [youtube] H5v3kku4y6Q: Downloading tv player API JSON
# [youtube] H5v3kku4y6Q: Downloading ios player API JSON
# [youtube] H5v3kku4y6Q: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=H5v3kku4y6Q
# [youtube] H5v3kku4y6Q: Downloading webpage
# [youtube] H5v3kku4y6Q: Downloading tv client config
# [youtube] H5v3kku4y6Q: Downloading tv player API JSON
# [youtube] H5v3kku4y6Q: Downloading ios player API JSON
# [youtube] H5v3kku4y6Q: Downloading m3u8 information
# [info] H5v3kku4y6Q: Downloading 1 format(s): 251
# [download] Destination: results/harry_5_1.mp3
# [download] 100% of    2.62MiB in 00:00:00 at 45.12MiB/s
# Download complete: results/harry_5_1.mp3
#
# === Descargando canción 7/40 ===
# Link: https://www.youtube.com/watch?v=XwxLwG2_Sxk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XwxLwG2_Sxk
# [youtube] XwxLwG2_Sxk: Downloading webpage
# [youtube] XwxLwG2_Sxk: Downloading tv client config
# [youtube] XwxLwG2_Sxk: Downloading tv player API JSON
# [youtube] XwxLwG2_Sxk: Downloading ios player API JSON
# [youtube] XwxLwG2_Sxk: Downloading m3u8 information
# [info] Testing format 616
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XwxLwG2_Sxk
# [youtube] XwxLwG2_Sxk: Downloading webpage
# [youtube] XwxLwG2_Sxk: Downloading tv client config
# [youtube] XwxLwG2_Sxk: Downloading tv player API JSON
# [youtube] XwxLwG2_Sxk: Downloading ios player API JSON
# [youtube] XwxLwG2_Sxk: Downloading m3u8 information
# [info] XwxLwG2_Sxk: Downloading 1 format(s): 251
# [download] Destination: results/theweeknd_6_1.mp3
# [download] 100% of    3.16MiB in 00:00:00 at 32.98MiB/s
# Download complete: results/theweeknd_6_1.mp3
#
# === Descargando canción 8/40 ===
# Link: https://www.youtube.com/watch?v=TUVcZfQe-Kw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TUVcZfQe-Kw
# [youtube] TUVcZfQe-Kw: Downloading webpage
# [youtube] TUVcZfQe-Kw: Downloading tv client config
# [youtube] TUVcZfQe-Kw: Downloading tv player API JSON
# [youtube] TUVcZfQe-Kw: Downloading ios player API JSON
# [youtube] TUVcZfQe-Kw: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TUVcZfQe-Kw
# [youtube] TUVcZfQe-Kw: Downloading webpage
# [youtube] TUVcZfQe-Kw: Downloading tv client config
# [youtube] TUVcZfQe-Kw: Downloading tv player API JSON
# [youtube] TUVcZfQe-Kw: Downloading ios player API JSON
# [youtube] TUVcZfQe-Kw: Downloading m3u8 information
# [info] TUVcZfQe-Kw: Downloading 1 format(s): 251
# [download] Destination: results/dualipa_7_1.mp3
# [download] 100% of    3.55MiB in 00:00:00 at 21.53MiB/s
# Download complete: results/dualipa_7_1.mp3
#
# === Descargando canción 9/40 ===
# Link: https://www.youtube.com/watch?v=pGHK4UPCtXk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pGHK4UPCtXk
# [youtube] pGHK4UPCtXk: Downloading webpage
# [youtube] pGHK4UPCtXk: Downloading tv client config
# [youtube] pGHK4UPCtXk: Downloading tv player API JSON
# [youtube] pGHK4UPCtXk: Downloading ios player API JSON
# [youtube] pGHK4UPCtXk: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pGHK4UPCtXk
# [youtube] pGHK4UPCtXk: Downloading webpage
# [youtube] pGHK4UPCtXk: Downloading tv client config
# [youtube] pGHK4UPCtXk: Downloading tv player API JSON
# [youtube] pGHK4UPCtXk: Downloading ios player API JSON
# [youtube] pGHK4UPCtXk: Downloading m3u8 information
# [info] pGHK4UPCtXk: Downloading 1 format(s): 251
# [download] Destination: results/taylor_8_1.mp3
# [download] 100% of    3.01MiB in 00:00:00 at 16.32MiB/s
# Download complete: results/taylor_8_1.mp3
#
# === Descargando canción 10/40 ===
# Link: https://www.youtube.com/watch?v=Nnl-qn3vlLU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Nnl-qn3vlLU
# [youtube] Nnl-qn3vlLU: Downloading webpage
# [youtube] Nnl-qn3vlLU: Downloading tv client config
# [youtube] Nnl-qn3vlLU: Downloading tv player API JSON
# [youtube] Nnl-qn3vlLU: Downloading ios player API JSON
# [youtube] Nnl-qn3vlLU: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Nnl-qn3vlLU
# [youtube] Nnl-qn3vlLU: Downloading webpage
# [youtube] Nnl-qn3vlLU: Downloading tv client config
# [youtube] Nnl-qn3vlLU: Downloading tv player API JSON
# [youtube] Nnl-qn3vlLU: Downloading ios player API JSON
# [youtube] Nnl-qn3vlLU: Downloading m3u8 information
# [info] Nnl-qn3vlLU: Downloading 1 format(s): 251
# [download] Destination: results/edsheeran_9_1.mp3
# [download] 100% of    3.35MiB in 00:00:00 at 35.16MiB/s
# Download complete: results/edsheeran_9_1.mp3
#
# === Descargando canción 11/40 ===
# Link: https://www.youtube.com/watch?v=ca48oMV59LU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ca48oMV59LU
# [youtube] ca48oMV59LU: Downloading webpage
# [youtube] ca48oMV59LU: Downloading tv client config
# [youtube] ca48oMV59LU: Downloading tv player API JSON
# [youtube] ca48oMV59LU: Downloading ios player API JSON
# [youtube] ca48oMV59LU: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ca48oMV59LU
# [youtube] ca48oMV59LU: Downloading webpage
# [youtube] ca48oMV59LU: Downloading tv client config
# [youtube] ca48oMV59LU: Downloading tv player API JSON
# [youtube] ca48oMV59LU: Downloading ios player API JSON
# [youtube] ca48oMV59LU: Downloading m3u8 information
# [info] ca48oMV59LU: Downloading 1 format(s): 251
# [download] Destination: results/karolg_10_1.mp3
# [download] 100% of    3.34MiB in 00:00:00 at 41.01MiB/s
# Download complete: results/karolg_10_1.mp3
#
# === Descargando canción 12/40 ===
# Link: https://www.youtube.com/watch?v=YwJAHTXQJjQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YwJAHTXQJjQ
# [youtube] YwJAHTXQJjQ: Downloading webpage
# [youtube] YwJAHTXQJjQ: Downloading tv client config
# [youtube] YwJAHTXQJjQ: Downloading tv player API JSON
# [youtube] YwJAHTXQJjQ: Downloading ios player API JSON
# [youtube] YwJAHTXQJjQ: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YwJAHTXQJjQ
# [youtube] YwJAHTXQJjQ: Downloading webpage
# [youtube] YwJAHTXQJjQ: Downloading tv client config
# [youtube] YwJAHTXQJjQ: Downloading tv player API JSON
# [youtube] YwJAHTXQJjQ: Downloading ios player API JSON
# [youtube] YwJAHTXQJjQ: Downloading m3u8 information
# [info] YwJAHTXQJjQ: Downloading 1 format(s): 251
# [download] Destination: results/karolyshakira_11_1.mp3
# [download] 100% of    3.18MiB in 00:00:00 at 29.55MiB/s
# Download complete: results/karolyshakira_11_1.mp3
#
# === Descargando canción 13/40 ===
# Link: https://www.youtube.com/watch?v=BXd-NIVqfBc
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BXd-NIVqfBc
# [youtube] BXd-NIVqfBc: Downloading webpage
# [youtube] BXd-NIVqfBc: Downloading tv client config
# [youtube] BXd-NIVqfBc: Downloading tv player API JSON
# [youtube] BXd-NIVqfBc: Downloading ios player API JSON
# [youtube] BXd-NIVqfBc: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BXd-NIVqfBc
# [youtube] BXd-NIVqfBc: Downloading webpage
# [youtube] BXd-NIVqfBc: Downloading tv client config
# [youtube] BXd-NIVqfBc: Downloading tv player API JSON
# [youtube] BXd-NIVqfBc: Downloading ios player API JSON
# [youtube] BXd-NIVqfBc: Downloading m3u8 information
# [info] BXd-NIVqfBc: Downloading 1 format(s): 251
# [download] Destination: results/sebastianyatra_12_1.mp3
# [download] 100% of    3.09MiB in 00:00:00 at 23.86MiB/s
# Download complete: results/sebastianyatra_12_1.mp3
#
# === Descargando canción 14/40 ===
# Link: https://www.youtube.com/watch?v=10EX-_h4pYc
# [youtube] Extracting URL: https://www.youtube.com/watch?v=10EX-_h4pYc
# [youtube] 10EX-_h4pYc: Downloading webpage
# [youtube] 10EX-_h4pYc: Downloading tv client config
# [youtube] 10EX-_h4pYc: Downloading tv player API JSON
# [youtube] 10EX-_h4pYc: Downloading ios player API JSON
# [youtube] 10EX-_h4pYc: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=10EX-_h4pYc
# [youtube] 10EX-_h4pYc: Downloading webpage
# [youtube] 10EX-_h4pYc: Downloading tv client config
# [youtube] 10EX-_h4pYc: Downloading tv player API JSON
# [youtube] 10EX-_h4pYc: Downloading ios player API JSON
# [youtube] 10EX-_h4pYc: Downloading m3u8 information
# [info] 10EX-_h4pYc: Downloading 1 format(s): 251
# [download] Destination: results/badbunny_13_1.mp3
# [download] 100% of    4.48MiB in 00:00:00 at 13.42MiB/s
# Download complete: results/badbunny_13_1.mp3
#
# === Descargando canción 15/40 ===
# Link: https://www.youtube.com/watch?v=y8rBC6GCUjg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y8rBC6GCUjg
# [youtube] y8rBC6GCUjg: Downloading webpage
# [youtube] y8rBC6GCUjg: Downloading tv client config
# [youtube] y8rBC6GCUjg: Downloading tv player API JSON
# [youtube] y8rBC6GCUjg: Downloading ios player API JSON
# [youtube] y8rBC6GCUjg: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y8rBC6GCUjg
# [youtube] y8rBC6GCUjg: Downloading webpage
# [youtube] y8rBC6GCUjg: Downloading tv client config
# [youtube] y8rBC6GCUjg: Downloading tv player API JSON
# [youtube] y8rBC6GCUjg: Downloading ios player API JSON
# WARNING: [youtube] y8rBC6GCUjg: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# WARNING: [youtube] y8rBC6GCUjg: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] y8rBC6GCUjg: Downloading m3u8 information
# [info] y8rBC6GCUjg: Downloading 1 format(s): 234
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 36
# [download] Destination: results/julieta_14_1.mp3
# [download] 100% of    2.89MiB in 00:00:01 at 2.88MiB/s
# Download complete: results/julieta_14_1.mp3
#
# === Descargando canción 16/40 ===
# Link: https://www.youtube.com/watch?v=Ic5vxw3eijY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ic5vxw3eijY
# [youtube] Ic5vxw3eijY: Downloading webpage
# [youtube] Ic5vxw3eijY: Downloading tv client config
# [youtube] Ic5vxw3eijY: Downloading tv player API JSON
# [youtube] Ic5vxw3eijY: Downloading ios player API JSON
# [youtube] Ic5vxw3eijY: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ic5vxw3eijY
# [youtube] Ic5vxw3eijY: Downloading webpage
# [youtube] Ic5vxw3eijY: Downloading tv client config
# [youtube] Ic5vxw3eijY: Downloading tv player API JSON
# [youtube] Ic5vxw3eijY: Downloading ios player API JSON
# [youtube] Ic5vxw3eijY: Downloading m3u8 information
# [info] Ic5vxw3eijY: Downloading 1 format(s): 251
# [download] Destination: results/estelle_15_1.mp3
# [download] 100% of    3.92MiB in 00:00:00 at 27.68MiB/s
# Download complete: results/estelle_15_1.mp3
#
# === Descargando canción 17/40 ===
# Link: https://www.youtube.com/watch?v=qExd-3oCTl4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qExd-3oCTl4
# [youtube] qExd-3oCTl4: Downloading webpage
# [youtube] qExd-3oCTl4: Downloading tv client config
# [youtube] qExd-3oCTl4: Downloading tv player API JSON
# [youtube] qExd-3oCTl4: Downloading ios player API JSON
# [youtube] qExd-3oCTl4: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qExd-3oCTl4
# [youtube] qExd-3oCTl4: Downloading webpage
# [youtube] qExd-3oCTl4: Downloading tv client config
# [youtube] qExd-3oCTl4: Downloading tv player API JSON
# [youtube] qExd-3oCTl4: Downloading ios player API JSON
# [youtube] qExd-3oCTl4: Downloading m3u8 information
# [info] qExd-3oCTl4: Downloading 1 format(s): 251
# [download] Destination: results/carlosbaute_16_1.mp3
# [download] 100% of    3.80MiB in 00:00:00 at 60.11MiB/s
# Download complete: results/carlosbaute_16_1.mp3
#
# === Descargando canción 18/40 ===
# Link: https://www.youtube.com/watch?v=EDkQB9b3cBw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EDkQB9b3cBw
# [youtube] EDkQB9b3cBw: Downloading webpage
# [youtube] EDkQB9b3cBw: Downloading tv client config
# [youtube] EDkQB9b3cBw: Downloading tv player API JSON
# [youtube] EDkQB9b3cBw: Downloading ios player API JSON
# [youtube] EDkQB9b3cBw: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EDkQB9b3cBw
# [youtube] EDkQB9b3cBw: Downloading webpage
# [youtube] EDkQB9b3cBw: Downloading tv client config
# [youtube] EDkQB9b3cBw: Downloading tv player API JSON
# [youtube] EDkQB9b3cBw: Downloading ios player API JSON
# [youtube] EDkQB9b3cBw: Downloading m3u8 information
# [info] EDkQB9b3cBw: Downloading 1 format(s): 251
# [download] Destination: results/mana_17_1.mp3
# [download] 100% of    3.94MiB in 00:00:00 at 63.71MiB/s
# Download complete: results/mana_17_1.mp3
#
# === Descargando canción 19/40 ===
# Link: https://www.youtube.com/watch?v=voxgN3Dhjuo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=voxgN3Dhjuo
# [youtube] voxgN3Dhjuo: Downloading webpage
# [youtube] voxgN3Dhjuo: Downloading tv client config
# [youtube] voxgN3Dhjuo: Downloading tv player API JSON
# [youtube] voxgN3Dhjuo: Downloading ios player API JSON
# [youtube] voxgN3Dhjuo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=voxgN3Dhjuo
# [youtube] voxgN3Dhjuo: Downloading webpage
# [youtube] voxgN3Dhjuo: Downloading tv client config
# [youtube] voxgN3Dhjuo: Downloading tv player API JSON
# [youtube] voxgN3Dhjuo: Downloading ios player API JSON
# [youtube] voxgN3Dhjuo: Downloading m3u8 information
# [info] voxgN3Dhjuo: Downloading 1 format(s): 251
# [download] Destination: results/juanes_18_1.mp3
# [download] 100% of    2.96MiB in 00:00:00 at 18.03MiB/s
# Download complete: results/juanes_18_1.mp3
#
# === Descargando canción 20/40 ===
# Link: https://www.youtube.com/watch?v=tIpzfs5tBJU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tIpzfs5tBJU
# [youtube] tIpzfs5tBJU: Downloading webpage
# [youtube] tIpzfs5tBJU: Downloading tv client config
# [youtube] tIpzfs5tBJU: Downloading tv player API JSON
# [youtube] tIpzfs5tBJU: Downloading ios player API JSON
# [youtube] tIpzfs5tBJU: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tIpzfs5tBJU
# [youtube] tIpzfs5tBJU: Downloading webpage
# [youtube] tIpzfs5tBJU: Downloading tv client config
# [youtube] tIpzfs5tBJU: Downloading tv player API JSON
# [youtube] tIpzfs5tBJU: Downloading ios player API JSON
# [youtube] tIpzfs5tBJU: Downloading m3u8 information
# [info] tIpzfs5tBJU: Downloading 1 format(s): 251
# [download] Destination: results/julieta_19_1.mp3
# [download] 100% of    3.47MiB in 00:00:00 at 26.83MiB/s
# Download complete: results/julieta_19_1.mp3
#
# === Descargando canción 21/40 ===
# Link: https://www.youtube.com/watch?v=yry3rgGlRUw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yry3rgGlRUw
# [youtube] yry3rgGlRUw: Downloading webpage
# [youtube] yry3rgGlRUw: Downloading tv client config
# [youtube] yry3rgGlRUw: Downloading tv player API JSON
# [youtube] yry3rgGlRUw: Downloading ios player API JSON
# [youtube] yry3rgGlRUw: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yry3rgGlRUw
# [youtube] yry3rgGlRUw: Downloading webpage
# [youtube] yry3rgGlRUw: Downloading tv client config
# [youtube] yry3rgGlRUw: Downloading tv player API JSON
# [youtube] yry3rgGlRUw: Downloading ios player API JSON
# [youtube] yry3rgGlRUw: Downloading m3u8 information
# [info] yry3rgGlRUw: Downloading 1 format(s): 251
# [download] Destination: results/binomiodeoro_20_2.mp3
# [download] 100% of    4.37MiB in 00:00:00 at 75.85MiB/s
# Download complete: results/binomiodeoro_20_2.mp3
#
# === Descargando canción 22/40 ===
# Link: https://www.youtube.com/watch?v=SKV6zQyeJeo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SKV6zQyeJeo
# [youtube] SKV6zQyeJeo: Downloading webpage
# [youtube] SKV6zQyeJeo: Downloading tv client config
# [youtube] SKV6zQyeJeo: Downloading tv player API JSON
# [youtube] SKV6zQyeJeo: Downloading ios player API JSON
# [youtube] SKV6zQyeJeo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SKV6zQyeJeo
# [youtube] SKV6zQyeJeo: Downloading webpage
# [youtube] SKV6zQyeJeo: Downloading tv client config
# [youtube] SKV6zQyeJeo: Downloading tv player API JSON
# [youtube] SKV6zQyeJeo: Downloading ios player API JSON
# [youtube] SKV6zQyeJeo: Downloading m3u8 information
# [info] SKV6zQyeJeo: Downloading 1 format(s): 251
# [download] Destination: results/diomedes_21_2.mp3
# [download] 100% of    5.02MiB in 00:00:00 at 44.86MiB/s
# Download complete: results/diomedes_21_2.mp3
#
# === Descargando canción 23/40 ===
# Link: https://www.youtube.com/watch?v=uSG9ejcx7UM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uSG9ejcx7UM
# [youtube] uSG9ejcx7UM: Downloading webpage
# [youtube] uSG9ejcx7UM: Downloading tv client config
# [youtube] uSG9ejcx7UM: Downloading tv player API JSON
# [youtube] uSG9ejcx7UM: Downloading ios player API JSON
# [youtube] uSG9ejcx7UM: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uSG9ejcx7UM
# [youtube] uSG9ejcx7UM: Downloading webpage
# [youtube] uSG9ejcx7UM: Downloading tv client config
# [youtube] uSG9ejcx7UM: Downloading tv player API JSON
# [youtube] uSG9ejcx7UM: Downloading ios player API JSON
# [youtube] uSG9ejcx7UM: Downloading m3u8 information
# [info] uSG9ejcx7UM: Downloading 1 format(s): 251
# [download] Destination: results/diomedes_22_2.mp3
# [download] 100% of    4.69MiB in 00:00:00 at 79.18MiB/s
# Download complete: results/diomedes_22_2.mp3
#
# === Descargando canción 24/40 ===
# Link: https://www.youtube.com/watch?v=34K2dYw_od8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=34K2dYw_od8
# [youtube] 34K2dYw_od8: Downloading webpage
# [youtube] 34K2dYw_od8: Downloading tv client config
# [youtube] 34K2dYw_od8: Downloading tv player API JSON
# [youtube] 34K2dYw_od8: Downloading ios player API JSON
# [youtube] 34K2dYw_od8: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=34K2dYw_od8
# [youtube] 34K2dYw_od8: Downloading webpage
# [youtube] 34K2dYw_od8: Downloading tv client config
# [youtube] 34K2dYw_od8: Downloading tv player API JSON
# [youtube] 34K2dYw_od8: Downloading ios player API JSON
# [youtube] 34K2dYw_od8: Downloading m3u8 information
# [info] 34K2dYw_od8: Downloading 1 format(s): 251
# [download] Destination: results/silvestre_23_2.mp3
# [download] 100% of    4.05MiB in 00:00:00 at 61.45MiB/s
# Download complete: results/silvestre_23_2.mp3
#
# === Descargando canción 25/40 ===
# Link: https://www.youtube.com/watch?v=C809y6QczUw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=C809y6QczUw
# [youtube] C809y6QczUw: Downloading webpage
# [youtube] C809y6QczUw: Downloading tv client config
# [youtube] C809y6QczUw: Downloading tv player API JSON
# [youtube] C809y6QczUw: Downloading ios player API JSON
# [youtube] C809y6QczUw: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=C809y6QczUw
# [youtube] C809y6QczUw: Downloading webpage
# [youtube] C809y6QczUw: Downloading tv client config
# [youtube] C809y6QczUw: Downloading tv player API JSON
# [youtube] C809y6QczUw: Downloading ios player API JSON
# WARNING: [youtube] C809y6QczUw: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# WARNING: [youtube] C809y6QczUw: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] C809y6QczUw: Downloading m3u8 information
# [info] C809y6QczUw: Downloading 1 format(s): 234
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 45
# [download] Destination: results/miguelmorales_24_2.mp3
# [download] 100% of    4.83MiB in 00:00:01 at 3.78MiB/s
# Download complete: results/miguelmorales_24_2.mp3
#
# === Descargando canción 26/40 ===
# Link: https://www.youtube.com/watch?v=l6IRVJUBe7c
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l6IRVJUBe7c
# [youtube] l6IRVJUBe7c: Downloading webpage
# [youtube] l6IRVJUBe7c: Downloading tv client config
# [youtube] l6IRVJUBe7c: Downloading tv player API JSON
# [youtube] l6IRVJUBe7c: Downloading ios player API JSON
# [youtube] l6IRVJUBe7c: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l6IRVJUBe7c
# [youtube] l6IRVJUBe7c: Downloading webpage
# [youtube] l6IRVJUBe7c: Downloading tv client config
# [youtube] l6IRVJUBe7c: Downloading tv player API JSON
# [youtube] l6IRVJUBe7c: Downloading ios player API JSON
# [youtube] l6IRVJUBe7c: Downloading m3u8 information
# [info] l6IRVJUBe7c: Downloading 1 format(s): 251
# [download] Destination: results/diomedes_25_2.mp3
# [download] 100% of    4.66MiB in 00:00:00 at 26.11MiB/s
# Download complete: results/diomedes_25_2.mp3
#
# === Descargando canción 27/40 ===
# Link: https://www.youtube.com/watch?v=t-6sW5YMrks
# [youtube] Extracting URL: https://www.youtube.com/watch?v=t-6sW5YMrks
# [youtube] t-6sW5YMrks: Downloading webpage
# [youtube] t-6sW5YMrks: Downloading tv client config
# [youtube] t-6sW5YMrks: Downloading tv player API JSON
# [youtube] t-6sW5YMrks: Downloading ios player API JSON
# WARNING: [youtube] t-6sW5YMrks: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# WARNING: [youtube] t-6sW5YMrks: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] t-6sW5YMrks: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=t-6sW5YMrks
# [youtube] t-6sW5YMrks: Downloading webpage
# [youtube] t-6sW5YMrks: Downloading tv client config
# [youtube] t-6sW5YMrks: Downloading tv player API JSON
# [youtube] t-6sW5YMrks: Downloading ios player API JSON
# [youtube] t-6sW5YMrks: Downloading m3u8 information
# [info] t-6sW5YMrks: Downloading 1 format(s): 251
# [download] Destination: results/petermanjarres_26_2.mp3
# [download] 100% of    3.72MiB in 00:00:00 at 31.67MiB/s
# Download complete: results/petermanjarres_26_2.mp3
#
# === Descargando canción 28/40 ===
# Link: https://www.youtube.com/watch?v=NMQLxnaOpuk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NMQLxnaOpuk
# [youtube] NMQLxnaOpuk: Downloading webpage
# [youtube] NMQLxnaOpuk: Downloading tv client config
# [youtube] NMQLxnaOpuk: Downloading tv player API JSON
# [youtube] NMQLxnaOpuk: Downloading ios player API JSON
# [youtube] NMQLxnaOpuk: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NMQLxnaOpuk
# [youtube] NMQLxnaOpuk: Downloading webpage
# [youtube] NMQLxnaOpuk: Downloading tv client config
# [youtube] NMQLxnaOpuk: Downloading tv player API JSON
# [youtube] NMQLxnaOpuk: Downloading ios player API JSON
# [youtube] NMQLxnaOpuk: Downloading m3u8 information
# [info] NMQLxnaOpuk: Downloading 1 format(s): 251
# [download] Destination: results/petermanjarres_27_2.mp3
# [download] 100% of    5.29MiB in 00:00:00 at 10.06MiB/s
# Download complete: results/petermanjarres_27_2.mp3
#
# === Descargando canción 29/40 ===
# Link: https://www.youtube.com/watch?v=oYobLFYuTXs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oYobLFYuTXs
# [youtube] oYobLFYuTXs: Downloading webpage
# [youtube] oYobLFYuTXs: Downloading tv client config
# [youtube] oYobLFYuTXs: Downloading tv player API JSON
# [youtube] oYobLFYuTXs: Downloading ios player API JSON
# [youtube] oYobLFYuTXs: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oYobLFYuTXs
# [youtube] oYobLFYuTXs: Downloading webpage
# [youtube] oYobLFYuTXs: Downloading tv client config
# [youtube] oYobLFYuTXs: Downloading tv player API JSON
# [youtube] oYobLFYuTXs: Downloading ios player API JSON
# WARNING: [youtube] oYobLFYuTXs: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# WARNING: [youtube] oYobLFYuTXs: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] oYobLFYuTXs: Downloading m3u8 information
# [info] oYobLFYuTXs: Downloading 1 format(s): 234
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 48
# [download] Destination: results/lacombinacion_28_2.mp3
# [download] 100% of    4.71MiB in 00:00:01 at 2.99MiB/s
# Download complete: results/lacombinacion_28_2.mp3
#
# === Descargando canción 30/40 ===
# Link: https://www.youtube.com/watch?v=RT0shE8McTQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RT0shE8McTQ
# [youtube] RT0shE8McTQ: Downloading webpage
# [youtube] RT0shE8McTQ: Downloading tv client config
# [youtube] RT0shE8McTQ: Downloading tv player API JSON
# [youtube] RT0shE8McTQ: Downloading ios player API JSON
# [youtube] RT0shE8McTQ: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RT0shE8McTQ
# [youtube] RT0shE8McTQ: Downloading webpage
# [youtube] RT0shE8McTQ: Downloading tv client config
# [youtube] RT0shE8McTQ: Downloading tv player API JSON
# [youtube] RT0shE8McTQ: Downloading ios player API JSON
# [youtube] RT0shE8McTQ: Downloading m3u8 information
# [info] RT0shE8McTQ: Downloading 1 format(s): 251
# [download] Destination: results/losembajadores_29_2.mp3
# [download] 100% of    4.22MiB in 00:00:00 at 12.60MiB/s
# Download complete: results/losembajadores_29_2.mp3
#
# === Descargando canción 31/40 ===
# Link: https://www.youtube.com/watch?v=UZFoar42-zg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UZFoar42-zg
# [youtube] UZFoar42-zg: Downloading webpage
# [youtube] UZFoar42-zg: Downloading tv client config
# [youtube] UZFoar42-zg: Downloading tv player API JSON
# [youtube] UZFoar42-zg: Downloading ios player API JSON
# [youtube] UZFoar42-zg: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UZFoar42-zg
# [youtube] UZFoar42-zg: Downloading webpage
# [youtube] UZFoar42-zg: Downloading tv client config
# [youtube] UZFoar42-zg: Downloading tv player API JSON
# [youtube] UZFoar42-zg: Downloading ios player API JSON
# [youtube] UZFoar42-zg: Downloading m3u8 information
# [info] UZFoar42-zg: Downloading 1 format(s): 251
# [download] Destination: results/diomedes_30_2.mp3
# [download] 100% of    4.42MiB in 00:00:00 at 29.28MiB/s
# Download complete: results/diomedes_30_2.mp3
#
# === Descargando canción 32/40 ===
# Link: https://www.youtube.com/watch?v=KPJ2oIEvffk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KPJ2oIEvffk
# [youtube] KPJ2oIEvffk: Downloading webpage
# [youtube] KPJ2oIEvffk: Downloading tv client config
# [youtube] KPJ2oIEvffk: Downloading tv player API JSON
# [youtube] KPJ2oIEvffk: Downloading ios player API JSON
# [youtube] KPJ2oIEvffk: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KPJ2oIEvffk
# [youtube] KPJ2oIEvffk: Downloading webpage
# [youtube] KPJ2oIEvffk: Downloading tv client config
# [youtube] KPJ2oIEvffk: Downloading tv player API JSON
# [youtube] KPJ2oIEvffk: Downloading ios player API JSON
# [youtube] KPJ2oIEvffk: Downloading m3u8 information
# [info] KPJ2oIEvffk: Downloading 1 format(s): 251
# [download] Destination: results/omargeles_31_2.mp3
# [download] 100% of    4.86MiB in 00:00:00 at 31.70MiB/s
# Download complete: results/omargeles_31_2.mp3
#
# === Descargando canción 33/40 ===
# Link: https://www.youtube.com/watch?v=IxNBiYXL2PU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IxNBiYXL2PU
# [youtube] IxNBiYXL2PU: Downloading webpage
# [youtube] IxNBiYXL2PU: Downloading tv client config
# [youtube] IxNBiYXL2PU: Downloading tv player API JSON
# [youtube] IxNBiYXL2PU: Downloading ios player API JSON
# [youtube] IxNBiYXL2PU: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IxNBiYXL2PU
# [youtube] IxNBiYXL2PU: Downloading webpage
# [youtube] IxNBiYXL2PU: Downloading tv client config
# [youtube] IxNBiYXL2PU: Downloading tv player API JSON
# [youtube] IxNBiYXL2PU: Downloading ios player API JSON
# WARNING: [youtube] IxNBiYXL2PU: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# WARNING: [youtube] IxNBiYXL2PU: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] IxNBiYXL2PU: Downloading m3u8 information
# [info] IxNBiYXL2PU: Downloading 1 format(s): 234
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 65
# [download] Destination: results/diomedes_32_2.mp3
# [download] 100% of    5.14MiB in 00:00:02 at 2.54MiB/s
# Download complete: results/diomedes_32_2.mp3
#
# === Descargando canción 34/40 ===
# Link: https://www.youtube.com/watch?v=itquaX8gH34
# [youtube] Extracting URL: https://www.youtube.com/watch?v=itquaX8gH34
# [youtube] itquaX8gH34: Downloading webpage
# [youtube] itquaX8gH34: Downloading tv client config
# [youtube] itquaX8gH34: Downloading tv player API JSON
# [youtube] itquaX8gH34: Downloading ios player API JSON
# [youtube] itquaX8gH34: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=itquaX8gH34
# [youtube] itquaX8gH34: Downloading webpage
# [youtube] itquaX8gH34: Downloading tv client config
# [youtube] itquaX8gH34: Downloading tv player API JSON
# [youtube] itquaX8gH34: Downloading ios player API JSON
# [youtube] itquaX8gH34: Downloading m3u8 information
# [info] itquaX8gH34: Downloading 1 format(s): 251
# [download] Destination: results/losdiablitos_33_2.mp3
# [download] 100% of    4.67MiB in 00:00:00 at 19.72MiB/s
# Download complete: results/losdiablitos_33_2.mp3
#
# === Descargando canción 35/40 ===
# Link: https://www.youtube.com/watch?v=hkgyOSrDL-I
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hkgyOSrDL-I
# [youtube] hkgyOSrDL-I: Downloading webpage
# [youtube] hkgyOSrDL-I: Downloading tv client config
# [youtube] hkgyOSrDL-I: Downloading tv player API JSON
# [youtube] hkgyOSrDL-I: Downloading ios player API JSON
# [youtube] hkgyOSrDL-I: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hkgyOSrDL-I
# [youtube] hkgyOSrDL-I: Downloading webpage
# [youtube] hkgyOSrDL-I: Downloading tv client config
# [youtube] hkgyOSrDL-I: Downloading tv player API JSON
# [youtube] hkgyOSrDL-I: Downloading ios player API JSON
# [youtube] hkgyOSrDL-I: Downloading m3u8 information
# [info] hkgyOSrDL-I: Downloading 1 format(s): 251
# [download] Destination: results/jorgeonate_34_2.mp3
# [download] 100% of    4.97MiB in 00:00:00 at 85.71MiB/s
# Download complete: results/jorgeonate_34_2.mp3
#
# === Descargando canción 36/40 ===
# Link: https://www.youtube.com/watch?v=mNFnaC4hjCI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mNFnaC4hjCI
# [youtube] mNFnaC4hjCI: Downloading webpage
# [youtube] mNFnaC4hjCI: Downloading tv client config
# [youtube] mNFnaC4hjCI: Downloading tv player API JSON
# [youtube] mNFnaC4hjCI: Downloading ios player API JSON
# [youtube] mNFnaC4hjCI: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mNFnaC4hjCI
# [youtube] mNFnaC4hjCI: Downloading webpage
# [youtube] mNFnaC4hjCI: Downloading tv client config
# [youtube] mNFnaC4hjCI: Downloading tv player API JSON
# [youtube] mNFnaC4hjCI: Downloading ios player API JSON
# [youtube] mNFnaC4hjCI: Downloading m3u8 information
# [info] mNFnaC4hjCI: Downloading 1 format(s): 251
# [download] Destination: results/binomiodeoro_35_2.mp3
# [download] 100% of    4.69MiB in 00:00:00 at 63.48MiB/s
# Download complete: results/binomiodeoro_35_2.mp3
#
# === Descargando canción 37/40 ===
# Link: https://www.youtube.com/watch?v=c3ohIPbDQbo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=c3ohIPbDQbo
# [youtube] c3ohIPbDQbo: Downloading webpage
# [youtube] c3ohIPbDQbo: Downloading tv client config
# [youtube] c3ohIPbDQbo: Downloading tv player API JSON
# [youtube] c3ohIPbDQbo: Downloading ios player API JSON
# [youtube] c3ohIPbDQbo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=c3ohIPbDQbo
# [youtube] c3ohIPbDQbo: Downloading webpage
# [youtube] c3ohIPbDQbo: Downloading tv client config
# [youtube] c3ohIPbDQbo: Downloading tv player API JSON
# [youtube] c3ohIPbDQbo: Downloading ios player API JSON
# [youtube] c3ohIPbDQbo: Downloading m3u8 information
# [info] c3ohIPbDQbo: Downloading 1 format(s): 251
# [download] Destination: results/binomiodeoro_36_2.mp3
# [download] 100% of    4.63MiB in 00:00:00 at 68.80MiB/s
# Download complete: results/binomiodeoro_36_2.mp3
#
# === Descargando canción 38/40 ===
# Link: https://www.youtube.com/watch?v=jsD3QWHtvGI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jsD3QWHtvGI
# [youtube] jsD3QWHtvGI: Downloading webpage
# [youtube] jsD3QWHtvGI: Downloading tv client config
# [youtube] jsD3QWHtvGI: Downloading tv player API JSON
# [youtube] jsD3QWHtvGI: Downloading ios player API JSON
# [youtube] jsD3QWHtvGI: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jsD3QWHtvGI
# [youtube] jsD3QWHtvGI: Downloading webpage
# [youtube] jsD3QWHtvGI: Downloading tv client config
# [youtube] jsD3QWHtvGI: Downloading tv player API JSON
# [youtube] jsD3QWHtvGI: Downloading ios player API JSON
# [youtube] jsD3QWHtvGI: Downloading m3u8 information
# [info] jsD3QWHtvGI: Downloading 1 format(s): 251
# [download] Destination: results/losgigantes_37_2.mp3
# [download] 100% of    5.39MiB in 00:00:00 at 79.92MiB/s
# Download complete: results/losgigantes_37_2.mp3
#
# === Descargando canción 39/40 ===
# Link: https://www.youtube.com/watch?v=UWTLJ91A8QA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UWTLJ91A8QA
# [youtube] UWTLJ91A8QA: Downloading webpage
# [youtube] UWTLJ91A8QA: Downloading tv client config
# [youtube] UWTLJ91A8QA: Downloading tv player API JSON
# [youtube] UWTLJ91A8QA: Downloading ios player API JSON
# [youtube] UWTLJ91A8QA: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UWTLJ91A8QA
# [youtube] UWTLJ91A8QA: Downloading webpage
# [youtube] UWTLJ91A8QA: Downloading tv client config
# [youtube] UWTLJ91A8QA: Downloading tv player API JSON
# [youtube] UWTLJ91A8QA: Downloading ios player API JSON
# [youtube] UWTLJ91A8QA: Downloading m3u8 information
# [info] UWTLJ91A8QA: Downloading 1 format(s): 251
# [download] Destination: results/losgigantes_38_2.mp3
# [download] 100% of    4.42MiB in 00:00:00 at 30.29MiB/s
# Download complete: results/losgigantes_38_2.mp3
#
# === Descargando canción 40/40 ===
# Link: https://www.youtube.com/watch?v=elCjRzvm5Hs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=elCjRzvm5Hs
# [youtube] elCjRzvm5Hs: Downloading webpage
# [youtube] elCjRzvm5Hs: Downloading tv client config
# [youtube] elCjRzvm5Hs: Downloading tv player API JSON
# [youtube] elCjRzvm5Hs: Downloading ios player API JSON
# [youtube] elCjRzvm5Hs: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=elCjRzvm5Hs
# [youtube] elCjRzvm5Hs: Downloading webpage
# [youtube] elCjRzvm5Hs: Downloading tv client config
# [youtube] elCjRzvm5Hs: Downloading tv player API JSON
# [youtube] elCjRzvm5Hs: Downloading ios player API JSON
# [youtube] elCjRzvm5Hs: Downloading m3u8 information
# [info] elCjRzvm5Hs: Downloading 1 format(s): 251
# [download] Destination: results/binomiodeoro_39_2.mp3
# [download] 100% of    4.92MiB in 00:00:00 at 34.69MiB/s
# Download complete: results/binomiodeoro_39_2.mp3
#
# Total de archivos WAV encontrados: 40 (deberían ser 10)
# 00 → carlosbaute_16_1.wav   segundos 10:15   género 1
# 01 → carlosbaute_16_1.wav   segundos 40:45   género 1
# 02 → carlosbaute_16_1.wav   segundos 70:75   género 1
# 03 → carlosbaute_16_1.wav   segundos 100:105   género 1
# 04 → carlosbaute_16_1.wav   segundos 130:135   género 1
# 05 → diomedes_30_2.wav   segundos 10:15   género 2
# 06 → diomedes_30_2.wav   segundos 40:45   género 2
# 07 → diomedes_30_2.wav   segundos 70:75   género 2
# 08 → diomedes_30_2.wav   segundos 100:105   género 2
# 09 → diomedes_30_2.wav   segundos 130:135   género 2
# 10 → omargeles_31_2.wav   segundos 10:15   género 2
# 11 → omargeles_31_2.wav   segundos 40:45   género 2
# 12 → omargeles_31_2.wav   segundos 70:75   género 2
# 13 → omargeles_31_2.wav   segundos 100:105   género 2
# 14 → omargeles_31_2.wav   segundos 130:135   género 2
# 15 → abba_0_1.wav   segundos 10:15   género 1
# 16 → abba_0_1.wav   segundos 40:45   género 1
# 17 → abba_0_1.wav   segundos 70:75   género 1
# 18 → abba_0_1.wav   segundos 100:105   género 1
# 19 → abba_0_1.wav   segundos 130:135   género 1
# 20 → abba_3_1.wav   segundos 10:15   género 1
# 21 → abba_3_1.wav   segundos 40:45   género 1
# 22 → abba_3_1.wav   segundos 70:75   género 1
# 23 → abba_3_1.wav   segundos 100:105   género 1
# 24 → abba_3_1.wav   segundos 130:135   género 1
# 25 → lacombinacion_28_2.wav   segundos 10:15   género 2
# 26 → lacombinacion_28_2.wav   segundos 40:45   género 2
# 27 → lacombinacion_28_2.wav   segundos 70:75   género 2
# 28 → lacombinacion_28_2.wav   segundos 100:105   género 2
# 29 → lacombinacion_28_2.wav   segundos 130:135   género 2
# 30 → daftpunk_1_1.wav   segundos 10:15   género 1
# 31 → daftpunk_1_1.wav   segundos 40:45   género 1
# 32 → daftpunk_1_1.wav   segundos 70:75   género 1
# 33 → daftpunk_1_1.wav   segundos 100:105   género 1
# 34 → daftpunk_1_1.wav   segundos 130:135   género 1
# 35 → karolyshakira_11_1.wav   segundos 10:15   género 1
# 36 → karolyshakira_11_1.wav   segundos 40:45   género 1
# 37 → karolyshakira_11_1.wav   segundos 70:75   género 1
# 38 → karolyshakira_11_1.wav   segundos 100:105   género 1
# 39 → karolyshakira_11_1.wav   segundos 130:135   género 1
# 40 → jorgeonate_34_2.wav   segundos 10:15   género 2
# 41 → jorgeonate_34_2.wav   segundos 40:45   género 2
# 42 → jorgeonate_34_2.wav   segundos 70:75   género 2
# 43 → jorgeonate_34_2.wav   segundos 100:105   género 2
# 44 → jorgeonate_34_2.wav   segundos 130:135   género 2
# 45 → harry_5_1.wav   segundos 10:15   género 1
# 46 → harry_5_1.wav   segundos 40:45   género 1
# 47 → harry_5_1.wav   segundos 70:75   género 1
# 48 → harry_5_1.wav   segundos 100:105   género 1
# 49 → harry_5_1.wav   segundos 130:135   género 1
# 50 → diomedes_22_2.wav   segundos 10:15   género 2
# 51 → diomedes_22_2.wav   segundos 40:45   género 2
# 52 → diomedes_22_2.wav   segundos 70:75   género 2
# 53 → diomedes_22_2.wav   segundos 100:105   género 2
# 54 → diomedes_22_2.wav   segundos 130:135   género 2
# 55 → miguelmorales_24_2.wav   segundos 10:15   género 2
# 56 → miguelmorales_24_2.wav   segundos 40:45   género 2
# 57 → miguelmorales_24_2.wav   segundos 70:75   género 2
# 58 → miguelmorales_24_2.wav   segundos 100:105   género 2
# 59 → miguelmorales_24_2.wav   segundos 130:135   género 2
# 60 → julieta_14_1.wav   segundos 10:15   género 1
# 61 → julieta_14_1.wav   segundos 40:45   género 1
# 62 → julieta_14_1.wav   segundos 70:75   género 1
# 63 → julieta_14_1.wav   segundos 100:105   género 1
# 64 → julieta_14_1.wav   segundos 130:135   género 1
# 65 → losgigantes_38_2.wav   segundos 10:15   género 2
# 66 → losgigantes_38_2.wav   segundos 40:45   género 2
# 67 → losgigantes_38_2.wav   segundos 70:75   género 2
# 68 → losgigantes_38_2.wav   segundos 100:105   género 2
# 69 → losgigantes_38_2.wav   segundos 130:135   género 2
# 70 → petermanjarres_26_2.wav   segundos 10:15   género 2
# 71 → petermanjarres_26_2.wav   segundos 40:45   género 2
# 72 → petermanjarres_26_2.wav   segundos 70:75   género 2
# 73 → petermanjarres_26_2.wav   segundos 100:105   género 2
# 74 → petermanjarres_26_2.wav   segundos 130:135   género 2
# 75 → sebastianyatra_12_1.wav   segundos 10:15   género 1
# 76 → sebastianyatra_12_1.wav   segundos 40:45   género 1
# 77 → sebastianyatra_12_1.wav   segundos 70:75   género 1
# 78 → sebastianyatra_12_1.wav   segundos 100:105   género 1
# 79 → sebastianyatra_12_1.wav   segundos 130:135   género 1
# 80 → badbunny_13_1.wav   segundos 10:15   género 1
# 81 → badbunny_13_1.wav   segundos 40:45   género 1
# 82 → badbunny_13_1.wav   segundos 70:75   género 1
# 83 → badbunny_13_1.wav   segundos 100:105   género 1
# 84 → badbunny_13_1.wav   segundos 130:135   género 1
# 85 → losgigantes_37_2.wav   segundos 10:15   género 2
# 86 → losgigantes_37_2.wav   segundos 40:45   género 2
# 87 → losgigantes_37_2.wav   segundos 70:75   género 2
# 88 → losgigantes_37_2.wav   segundos 100:105   género 2
# 89 → losgigantes_37_2.wav   segundos 130:135   género 2
# 90 → billieeilish_2_1.wav   segundos 10:15   género 1
# 91 → billieeilish_2_1.wav   segundos 40:45   género 1
# 92 → billieeilish_2_1.wav   segundos 70:75   género 1
# 93 → billieeilish_2_1.wav   segundos 100:105   género 1
# 94 → billieeilish_2_1.wav   segundos 130:135   género 1
# 95 → diomedes_32_2.wav   segundos 10:15   género 2
# 96 → diomedes_32_2.wav   segundos 40:45   género 2
# 97 → diomedes_32_2.wav   segundos 70:75   género 2
# 98 → diomedes_32_2.wav   segundos 100:105   género 2
# 99 → diomedes_32_2.wav   segundos 130:135   género 2
# 100 → losdiablitos_33_2.wav   segundos 10:15   género 2
# 101 → losdiablitos_33_2.wav   segundos 40:45   género 2
# 102 → losdiablitos_33_2.wav   segundos 70:75   género 2
# 103 → losdiablitos_33_2.wav   segundos 100:105   género 2
# 104 → losdiablitos_33_2.wav   segundos 130:135   género 2
# 105 → silvestre_23_2.wav   segundos 10:15   género 2
# 106 → silvestre_23_2.wav   segundos 40:45   género 2
# 107 → silvestre_23_2.wav   segundos 70:75   género 2
# 108 → silvestre_23_2.wav   segundos 100:105   género 2
# 109 → silvestre_23_2.wav   segundos 130:135   género 2
# 110 → roseybruno_4_1.wav   segundos 10:15   género 1
# 111 → roseybruno_4_1.wav   segundos 40:45   género 1
# 112 → roseybruno_4_1.wav   segundos 70:75   género 1
# 113 → roseybruno_4_1.wav   segundos 100:105   género 1
# 114 → roseybruno_4_1.wav   segundos 130:135   género 1
# 115 → estelle_15_1.wav   segundos 10:15   género 1
# 116 → estelle_15_1.wav   segundos 40:45   género 1
# 117 → estelle_15_1.wav   segundos 70:75   género 1
# 118 → estelle_15_1.wav   segundos 100:105   género 1
# 119 → estelle_15_1.wav   segundos 130:135   género 1
# 120 → mana_17_1.wav   segundos 10:15   género 1
# 121 → mana_17_1.wav   segundos 40:45   género 1
# 122 → mana_17_1.wav   segundos 70:75   género 1
# 123 → mana_17_1.wav   segundos 100:105   género 1
# 124 → mana_17_1.wav   segundos 130:135   género 1
# 125 → petermanjarres_27_2.wav   segundos 10:15   género 2
# 126 → petermanjarres_27_2.wav   segundos 40:45   género 2
# 127 → petermanjarres_27_2.wav   segundos 70:75   género 2
# 128 → petermanjarres_27_2.wav   segundos 100:105   género 2
# 129 → petermanjarres_27_2.wav   segundos 130:135   género 2
# 130 → dualipa_7_1.wav   segundos 10:15   género 1
# 131 → dualipa_7_1.wav   segundos 40:45   género 1
# 132 → dualipa_7_1.wav   segundos 70:75   género 1
# 133 → dualipa_7_1.wav   segundos 100:105   género 1
# 134 → dualipa_7_1.wav   segundos 130:135   género 1
# 135 → theweeknd_6_1.wav   segundos 10:15   género 1
# 136 → theweeknd_6_1.wav   segundos 40:45   género 1
# 137 → theweeknd_6_1.wav   segundos 70:75   género 1
# 138 → theweeknd_6_1.wav   segundos 100:105   género 1
# 139 → theweeknd_6_1.wav   segundos 130:135   género 1
# 140 → losembajadores_29_2.wav   segundos 10:15   género 2
# 141 → losembajadores_29_2.wav   segundos 40:45   género 2
# 142 → losembajadores_29_2.wav   segundos 70:75   género 2
# 143 → losembajadores_29_2.wav   segundos 100:105   género 2
# 144 → losembajadores_29_2.wav   segundos 130:135   género 2
# 145 → diomedes_25_2.wav   segundos 10:15   género 2
# 146 → diomedes_25_2.wav   segundos 40:45   género 2
# 147 → diomedes_25_2.wav   segundos 70:75   género 2
# 148 → diomedes_25_2.wav   segundos 100:105   género 2
# 149 → diomedes_25_2.wav   segundos 130:135   género 2
# 150 → edsheeran_9_1.wav   segundos 10:15   género 1
# 151 → edsheeran_9_1.wav   segundos 40:45   género 1
# 152 → edsheeran_9_1.wav   segundos 70:75   género 1
# 153 → edsheeran_9_1.wav   segundos 100:105   género 1
# 154 → edsheeran_9_1.wav   segundos 130:135   género 1
# 155 → taylor_8_1.wav   segundos 10:15   género 1
# 156 → taylor_8_1.wav   segundos 40:45   género 1
# 157 → taylor_8_1.wav   segundos 70:75   género 1
# 158 → taylor_8_1.wav   segundos 100:105   género 1
# 159 → taylor_8_1.wav   segundos 130:135   género 1
# 160 → binomiodeoro_39_2.wav   segundos 10:15   género 2
# 161 → binomiodeoro_39_2.wav   segundos 40:45   género 2
# 162 → binomiodeoro_39_2.wav   segundos 70:75   género 2
# 163 → binomiodeoro_39_2.wav   segundos 100:105   género 2
# 164 → binomiodeoro_39_2.wav   segundos 130:135   género 2
# 165 → binomiodeoro_20_2.wav   segundos 10:15   género 2
# 166 → binomiodeoro_20_2.wav   segundos 40:45   género 2
# 167 → binomiodeoro_20_2.wav   segundos 70:75   género 2
# 168 → binomiodeoro_20_2.wav   segundos 100:105   género 2
# 169 → binomiodeoro_20_2.wav   segundos 130:135   género 2
# 170 → julieta_19_1.wav   segundos 10:15   género 1
# 171 → julieta_19_1.wav   segundos 40:45   género 1
# 172 → julieta_19_1.wav   segundos 70:75   género 1
# 173 → julieta_19_1.wav   segundos 100:105   género 1
# 174 → julieta_19_1.wav   segundos 130:135   género 1
# 175 → binomiodeoro_36_2.wav   segundos 10:15   género 2
# 176 → binomiodeoro_36_2.wav   segundos 40:45   género 2
# 177 → binomiodeoro_36_2.wav   segundos 70:75   género 2
# 178 → binomiodeoro_36_2.wav   segundos 100:105   género 2
# 179 → binomiodeoro_36_2.wav   segundos 130:135   género 2
# 180 → diomedes_21_2.wav   segundos 10:15   género 2
# 181 → diomedes_21_2.wav   segundos 40:45   género 2
# 182 → diomedes_21_2.wav   segundos 70:75   género 2
# 183 → diomedes_21_2.wav   segundos 100:105   género 2
# 184 → diomedes_21_2.wav   segundos 130:135   género 2
# 185 → binomiodeoro_35_2.wav   segundos 10:15   género 2
# 186 → binomiodeoro_35_2.wav   segundos 40:45   género 2
# 187 → binomiodeoro_35_2.wav   segundos 70:75   género 2
# 188 → binomiodeoro_35_2.wav   segundos 100:105   género 2
# 189 → binomiodeoro_35_2.wav   segundos 130:135   género 2
# 190 → karolg_10_1.wav   segundos 10:15   género 1
# 191 → karolg_10_1.wav   segundos 40:45   género 1
# 192 → karolg_10_1.wav   segundos 70:75   género 1
# 193 → karolg_10_1.wav   segundos 100:105   género 1
# 194 → karolg_10_1.wav   segundos 130:135   género 1
# 195 → juanes_18_1.wav   segundos 10:15   género 1
# 196 → juanes_18_1.wav   segundos 40:45   género 1
# 197 → juanes_18_1.wav   segundos 70:75   género 1
# 198 → juanes_18_1.wav   segundos 100:105   género 1
# 199 → juanes_18_1.wav   segundos 130:135   género 1
#
# Forma de x_t: (200, 240000, 2)   → 50 segmentos de 5 s en estéreo
# Forma de label: (200, 1)
#
# Bin máximo seleccionado (f <= 7000 Hz):  35000  (f = 7000.0 Hz)
# Dataset final de espectros normalizados:  (200, 35000)   (50 muestras × 35000 bins)
# —> Entrenamiento completado: 50 vectores (5 s cada uno) con KNN guardado en modelo/knn_genre_detector.pkl
#
# → Se creó 'nuevo_fragmento_5s.wav' a partir del segmento #32 (género real = 1)
#
#
# ¡Género predicho para 'nuevo_fragmento_5s.wav': 1  (1=Pop, 2=Vallenato)!
#
# Error al predecir género: name 'Audio' is not defined

# %%
# !mkdir pages
# Out:
# mkdir: cannot create directory ‘pages’: File exists

# %%
# %%writefile 0_Detector.py

import streamlit as st

st.set_page_config(
    page_title="Detector de Generos Musicales🎵",
    page_icon="🎼",
)

st.write("# Bienvenido al detector de géneros musicales.🎼")

st.markdown(
    """
    ### Este panel interactivo en Streamlit te permitirá examinar un enlace de YouTube para determinar si la canción corresponde al género pop o vallenato.Emplearemos la Transformada Rápida de Fourier (FFT) para estudiar el espectro de frecuencias de la música y así reconocer rasgos distintivos de cada estilo musical.
"""
)
# Out:
# Overwriting 0_Detector.py

# %%
# %%writefile pages/1_🎵_Clasificador_Musical.py

import streamlit as st
import os
import numpy as np
import soundfile as sf
import joblib
import subprocess
import yt_dlp as youtube_dl
from sklearn.preprocessing import MinMaxScaler
from numpy.fft import rfft

# --- CONFIGURACIONES
SEGUNDO_INICIO = 0
DURACION = 10

# --- CARGA DEL MODELO
@st.cache_resource
def cargar_modelo():
    modelo = joblib.load("modelo/knn_genre_detector.pkl")
    return modelo

# --- DESCARGA Y CONVERSIÓN
def descargar_y_convertir(url: str, nombre_salida: str = "fragmento_usuario"):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': f"{nombre_salida}.mp3",
        'quiet': True,
    }
    with youtube_dl.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

    subprocess.call([
        'ffmpeg', '-y',
        '-ss', str(SEGUNDO_INICIO),
        '-t', str(DURACION),
        '-i', f"{nombre_salida}.mp3",
        '-ar', '48000',
        '-ac', '2',
        f"{nombre_salida}.wav"
    ])
    os.remove(f"{nombre_salida}.mp3")
    return f"{nombre_salida}.wav"

# --- PREDICCIÓN
def predecir_genero(path_wav, modelo):
    fs_ref = modelo['fs']
    fmax_idx = modelo['fmax_idx']
    scaler = modelo['scaler']
    knn = modelo['knn_model']

    x, fs_file = sf.read(path_wav)
    if fs_file != fs_ref:
        raise ValueError(f"Frecuencia esperada: {fs_ref} Hz, encontrada: {fs_file} Hz.")

    if x.ndim == 1:
        x = x[:fs_ref * DURACION]
        fft_mag = np.abs(rfft(x))
    else:
        x = x[:fs_ref * DURACION, :]
        fft0 = np.abs(rfft(x[:, 0]))
        fft1 = np.abs(rfft(x[:, 1]))
        fft_mag = (fft0 + fft1) / 2

    fft_mag = fft_mag[:fmax_idx].reshape(1, -1)
    fft_norm = scaler.transform(fft_mag)
    pred = knn.predict(fft_norm)[0]
    return int(pred)

# --- INTERFAZ STREAMLIT
st.title("🎵 Clasificador de Géneros Musicales")
st.write("Envía el link de una canción de YouTube (solo audio) y detectaremos si es **Pop** o **Vallenato**.")
st.markdown(f"🎧 Este detector analiza un fragmento de `{DURACION}` segundos desde el segundo `{SEGUNDO_INICIO}` de la canción.")

modelo = cargar_modelo()
url = st.text_input("🔗 Link de YouTube")

if url:
    try:
        st.info("🎧 Descargando y procesando audio...")
        wav_path = descargar_y_convertir(url)
        genero = predecir_genero(wav_path, modelo)
        st.success(f"🎶 Género detectado: {'Pop' if genero == 1 else 'Vallenato'}")
        audio_file = open(wav_path, 'rb')
        st.audio(audio_file.read(), format='audio/wav')
        audio_file.close()
    except Exception as e:
        st.error(f"❌ Error al procesar el audio: {e}")
# Out:
# Overwriting pages/1_🎵_Clasificador_Musical.py

# %%
# !mv 1_🎵_Clasificador_Musical.py pages/
# Out:
# mv: cannot stat '1_🎵_Clasificador_Musical.py': No such file or directory

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
# !mv cloudflared-linux-amd64 /usr/local/bin/cloudflared

#Ejecutar Streamlit
# !streamlit run 0_Detector.py &>/content/logs.txt & #Cambiar 0_👋_Hello.py por el nombre de tu archivo principal

#Exponer el puerto 8501 con Cloudflare Tunnel
# !cloudflared tunnel --url http://localhost:8501 > /content/cloudflared.log 2>&1 &

#Leer la URL pública generada por Cloudflare
import time
time.sleep(15)  # Esperar que se genere la URL

import re
found_context = False  # Indicador para saber si estamos en la sección correcta

with open('/content/cloudflared.log') as f:
    for line in f:
        #Detecta el inicio del contexto que nos interesa
        if "Your quick Tunnel has been created" in line:
            found_context = True

        #Busca una URL si ya se encontró el contexto relevante
        if found_context:
            match = re.search(r'https?://\S+', line)
            if match:
                url = match.group(0)  #Extrae la URL encontrada
                print(f'Tu aplicación está disponible en: {url}')
                break  #Termina el bucle después de encontrar la URL
# Out:
# --2025-06-15 02:44:03--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.6.0/cloudflared-linux-amd64 [following]
# --2025-06-15 02:44:03--  https://github.com/cloudflare/cloudflared/releases/download/2025.6.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/f1f89db3-aabb-45df-86d2-cc24c8707343?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-06-15T02%3A49%3A03Z&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-06-15T02%3A00%3A58Z&ske=2025-06-15T03%3A01%3A40Z&sks=b&skv=2018-11-09&sig=gJiboxNLE4kt53dLnoP1NBGGIjrvzuDpYdAAphCPDTY%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc0OTk1NTc0MywibmJmIjoxNzQ5OTU1NDQzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.9RDq4J4RF0ykQ6zeAxrT6amjQEmjS_W5UOxNqIYtJVs&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2025-06-15 02:44:03--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/f1f89db3-aabb-45df-86d2-cc24c8707343?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-06-15T02%3A49%3A03Z&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-06-15T02%3A00%3A58Z&ske=2025-06-15T03%3A01%3A40Z&sks=b&skv=2018-11-09&sig=gJiboxNLE4kt53dLnoP1NBGGIjrvzuDpYdAAphCPDTY%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc0OTk1NTc0MywibmJmIjoxNzQ5OTU1NDQzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.9RDq4J4RF0ykQ6zeAxrT6amjQEmjS_W5UOxNqIYtJVs&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40267046 (38M) [application/octet-stream]
# Saving to: ‘cloudflared-linux-amd64’
#
# cloudflared-linux-a 100%[===================>]  38.40M  --.-KB/s    in 0.1s
#
# 2025-06-15 02:44:03 (278 MB/s) - ‘cloudflared-linux-amd64’ saved [40267046/40267046]
#
# Tu aplicación está disponible en: https://ram-undertake-tft-survey.trycloudflare.com

# %%
import os

res = input("Digite (1) para finalizar la ejecución del Dashboard: ")

if res.upper() == "1":
    os.system("pkill streamlit")  # Termina el proceso de Streamlit
    print("El proceso de Streamlit ha sido finalizado.")
